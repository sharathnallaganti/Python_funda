# %%
"""
num = int(input("Enter the number: "))
rev_num = 0

while num!= 0 :
    digit = num %10 
    rev_num = rev_num * 10 + digit
    num//= 10

print(f"reverse number is: {rev_num}")

"""


num = int(input("Enter the number: "))
rev_num = 0

while num != 0:
    digit = num % 10
    rev_num = rev_num * 10 + digit
    num //= 10

print(f"Reverse number is: {rev_num}")
# Out:
# Enter the number:  9876
# Reverse number is: 6789

# %%
# Out:
# Enter the number:  123
# Reverse number is: 321

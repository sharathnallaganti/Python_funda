# %%
# The Fibonacci sequence is a type series where each number is the sum of the two that precede it.


a=0
b=1
for i in range(8):
    temp = a 
    a=b
    b=temp+b
print(temp,end=" ")

# %%
a=0
b=1
for i in range(8):
    temp = a 
    a=b
    b=temp+b
    print(temp,end=" ")

# %%
# 0,1,1,2,3,5,8,13,21

# fabinocci series is number series  in which number is sum of last 2 preceding numbers.

# if we print temp in loop it will give o/p as series

# if we print temp  outof loop it will give the  number which have that position





num=int(input("entar any number: "))
first =0
second=1
for i in range(num):
    print(first,end=" ")
    temp=first
    first=second
    second=temp+first

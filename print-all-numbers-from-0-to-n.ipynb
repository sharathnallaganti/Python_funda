# %%
nums = int(input("Enter how many numbers? : "))
for i in range(nums+1):
    print(i, end=" ")

# %%
nums = int(input("Enter how many numbers? : "))
for i in range(nums+1):
    if i<nums:
        print(i, end=",")
    else:
        print(i)

# %%
num  = int(input("Enter the number: "))
sum = 0

while num != 0:
    sum = sum + num %10
    num = num // 10

print(f"sum of the digits of is {sum}")
# Out:
# Enter the number:  564
# sum of the digits of is 15
